# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
wellProd = pd.read_csv("Data/well production.csv")
fileNames = wellProd["well name"]
wellDFs = [pd.read_csv("Data/" + el + ".csv") for el in fileNames]

# %%
wellDFs[0]
# Out:
#     easting  northing  porosity  permeability  Poisson's ratio  \
# 0   78000.0    1600.0      0.07         0.024            0.321
# 1   78076.0    1600.0      0.08         0.026            0.321
# 2   78153.0    1600.0      0.09         0.028            0.321
# 3   78229.0    1600.0      0.09         0.028            0.321
# 4   78306.0    1600.0      0.09         0.029            0.321
# ..      ...       ...       ...           ...              ...
# 95  85259.0    1600.0      0.04         0.009            0.332
# 96  85335.0    1600.0      0.04         0.009            0.332
# 97  85412.0    1600.0      0.07         0.017            0.332
# 98  85488.0    1600.0      0.05         0.010            0.332
# 99  85565.0    1600.0      0.07         0.022            0.332
#
#     Young's Modulus  water saturation  oil saturation  thickness (ft)  \
# 0       5434034.964          0.085075        0.914925       22.559422
# 1       5454122.821          0.084953        0.915047       22.710243
# 2       5474357.295          0.084833        0.915167       22.860497
# 3       5474357.295          0.084833        0.915167       22.860497
# 4       5494735.116          0.084714        0.915286       23.010171
# ..              ...               ...             ...             ...
# 95      7093843.633          0.078099        0.921901       31.217904
# 96      7093843.633          0.078099        0.921901       31.217904
# 97      7116690.153          0.077999        0.922001       31.291038
# 98      7139471.873          0.077899        0.922101       31.362604
# 99      7162186.325          0.077797        0.922203       31.432591
#
#     proppant weight (lbs)  pump rate (cubic feet/min)
# 0            1.167381e+06                  300.708062
# 1            2.586512e+06                  286.295447
# 2            1.549828e+06                  263.363298
# 3            8.719368e+05                  400.693413
# 4            1.168557e+06                  296.505463
# ..                    ...                         ...
# 95           1.661638e+05                  216.374907
# 96           1.317816e+06                  258.490214
# 97           1.369117e+06                  399.592126
# 98           5.641754e+05                  246.129655
# 99           1.072985e+06                  277.858007
#
# [100 rows x 11 columns]

# %%
eastings = [el.easting for el in wellDFs]
northings = [el.northing for el in wellDFs]

# %%
plt.scatter(eastings,northings)

# %%
plt.scatter(eastings[0],northings[0])

# %%
oils = wellProd["oil 1"]
oilPerPoint = [oils[i] / len(eastings[i]) for i in range(len(oils))]
oilPerPoint
# Out:
# [8.62,
#  2.28,
#  0.67,
#  2.56,
#  0.23,
#  0.62,
#  3.2,
#  1.68,
#  2.13,
#  0.88,
#  2.79,
#  1.64,
#  0.5,
#  1.2,
#  0.15,
#  0.99,
#  4.19,
#  3.06,
#  0.22,
#  2.94,
#  2.89,
#  1.13,
#  3.74,
#  1.96,
#  1.16,
#  5.59,
#  0.41,
#  3.53,
#  0.41,
#  2.82,
#  1.39,
#  0.82,
#  1.27,
#  0.35,
#  2.34,
#  1.47,
#  1.15,
#  0.09,
#  0.49,
#  0.92,
#  1.96,
#  1.92,
#  1.22,
#  1.76,
#  9.82,
#  4.14,
#  2.97,
#  0.73,
#  2.28,
#  1.07,
#  0.2,
#  0.08,
#  0.94,
#  0.51,
#  0.18,
#  0.28,
#  1.75,
#  1.32,
#  0.29,
#  3.18,
#  1.57,
#  1.06,
#  0.54,
#  0.83,
#  3.74,
#  1.57,
#  4.8,
#  1.67,
#  1.24,
#  0.83,
#  2.62,
#  3.27,
#  1.51,
#  5.06,
#  2.4,
#  1.53,
#  0.73,
#  0.49,
#  0.13,
#  0.3,
#  0.64,
#  3.78,
#  1.0,
#  1.62,
#  0.54,
#  0.79,
#  0.05,
#  1.13,
#  1.22,
#  1.16,
#  1.15,
#  1.51,
#  0.97,
#  3.14,
#  1.2,
#  9.81,
#  0.05,
#  10.53,
#  3.32,
#  5.42]
