# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
import keras
from keras.layers import Dense
import matplotlib.colors as colors
wells = []
##global scope variable for the path to where all the well data is stored
_PATH = "Data/"

# %% [markdown]
# # <span style="color:blue">This is a well class that will hold all the properties of a well and also will be able to perform relevant calculations for a given well</span>

# %%
class Well:
    ##This is a well class that will hold all the properties of a well
    ##and also will be able to do relevant calculations for a given well
    
    ##Once the data is set in the constructor, please do not change the values when they are accessed.
    ##Apparently I can't prevent this in Python, but I can at least advise against it.
    
    def __init__(self, easting, northing, porosity, permeability, PR, YM, wSaturation, oSaturation, thickness, proppant,
                 pumpRate, name, RF, Pa, FVF, oilByMonth, waterByMonth):
        self.easting = easting ##easting, areas with higher
        self.northing = northing ##northing, areas with higher
        self.porosity = porosity ##porosity, definitely something there
        self.permeability = permeability ##permeability,definitely something there
        self.PR = PR ##poissons's ratio, might be something. couple of outliers but general convergence
        self.YM = YM ##young's modulus, pyramid shape, probably something
        self.wSaturation = wSaturation ##water saturation, no correlation to production
        self.oSaturation = oSaturation ##oil saturation, no correlation to production
        self.thickness = thickness ##thickness, no correlation to production
        self.proppant = proppant ##proppant weight, maybe a correlation
        self.pumpRate = pumpRate ##pumpRate, probably a correlation
        self.name = name ##name
        self.RF = RF ##recovery factor, maybe something
        self.Pa = Pa ##average pressure, probably something
        self.FVF = FVF ##formation volume factor
        self.oilByMonth = oilByMonth ##oil produced in each month
        self.waterByMonth = waterByMonth ##water produced in each month
    
    ##returns the length of the well
    def getWellLength(self):
        return self.easting.max()-self.easting.min()
    
    #returns the total oil produced by the well
    def getTotalProduction(self):
        return self.oilByMonth.sum()
    
    ##returns the oil in place for this given well
    def getOilInPlace(self):
        return ((7758 * 360 * self.thickness.mean() * self.porosity.mean() * (1 - self.wSaturation.mean())) / self.FVF)
    
    ##returns the recoverable reserves of this well
    def getRecoverableReserves(self):
        return (self.getOilInPlace() * self.RF)
    
    ##Returns the production rate
    def InitialProduction(self):
        return (self.oilByMonth[0] * (math.exp((-1 * ((self.oilByMonth[11] - self.oilByMonth[0]) / 12) * time))))
        ##need to figure out how to plug in time (otherwise it will always equal first month production). also could be used
        ##to find the decline over time (where time is difference in production)
    
    ##Returns the economic limit of production
    def economicLimitROP(self):
        sumOilProduction = 0 
        for i in range(12):
            oil = getOilAtMonth(self, i)
            water = getWaterAtMonth(self, i)
            sumOilProduction += oil
            if(oil < water):
                return sumOilProduction
    
    ##Returns time in years
    def LifeOfReservoir(self):
        return ((1 / ((self.oilByMonth[11] - self.oilByMonth[0]) / 12)) * math.log((self.oilbyMonth[0]) / economicLimitROP(self)))
    
    ##Returns cumulative production in bbl
    def CumulativeProduction(self):
        return ((self.oilbyMonth[0] / declineRate) * math.log(self.oilbyMonth[0] / self.oilbyMonth[11]))
    
    ##this is the kind of functioning as a toString right now, almost no reason for it
    def getName(self):
        return self.name
    
    ##method to return oil produced in a given month
    def getOilAtMonth(self, n):
        if n > 12 or n < 1:
            ##bad
            return -1
        else:
            return self.oilByMonth[n]
    
    ##method to return water produced in a given month
    def getOilAtMonth(self, n):
        if n > 12 or n < 1:
            ##bad
            return -1
        else:
            return self.waterByMonth[n]
    
    ##method to display data for this well
    ##depth will be for getiing data at a given depth in a well. Not sure if or when I should implement this
    def displayData(self, depth = 0):
        if depth == 0:
            data = pd.read_csv(_PATH + self.name + ".csv")
        else:
            data = pd.read_csv(_PATH + self.name + ".csv")
            
        print("Displaying data for: " + self.name)
        print(data)
    
    ##Returns the number of frac stages for a well
    def getFracStages(self):
        count = 0
        for rate in self.pumpRate:
            if (pd.notnull(rate)):
                count+=1
        return count
    
    ##Returns the mean pump rate of a well
    def getAvgPumpRate(self):
        return self.pumpRate.mean(skipna = True)
    
    ##Returns the mean amount of proppant used in a well
    def getAvgProppant(self):
        return self.proppant.mean(skipna = True)
    
    ##Returns the mean easting coordinate value of a well
    def eastingAvg(self):
        return np.array(self.easting).mean()
    
    ##Returns the mean northing coordinate value of a well
    def northingAvg(self):
        return np.array(self.northing).mean()
    
    ##Returns the mean porosity value of a well
    def porosityAvg(self):
        return np.array(self.porosity).mean()
    
    ##Returns the mean permeability value of a well
    def permeabilityAvg(self):
        return np.array(self.permeability).mean()

    ##method to take the data given, create a well object and store it in wells
    def createWells():
        wellProduction = pd.read_csv(_PATH + "well production.csv")
        for i in range(100):
        ##for every well
            ##get all the data from the well production csv
            name = wellProduction.at[i, "well name"]
            ap = wellProduction.at[i, "average pressure (Pa)"]
            RF = wellProduction.at[i, "recovery factor"]
            FVF = wellProduction.at[i, "formation volume factor"]
            oil = wellProduction.iloc[i, 4:16] ##oil per month
            water = wellProduction.iloc[i, 16:28] ##water per month
            ##now that we have the name of the well, we can use that to access its
            ##own csv file and get that data
            wellDF = pd.read_csv(_PATH + name + ".csv")
            e = wellDF["easting"]
            n = wellDF["northing"]
            p = wellDF["porosity"]
            perm = wellDF["permeability"]
            pr = wellDF["Poisson's ratio"]
            ym = wellDF["Young's Modulus"]
            ws = wellDF["water saturation"]
            os = wellDF["oil saturation"]
            thick = wellDF["thickness (ft)"]
            prop = wellDF["proppant weight (lbs)"]
            pump = wellDF["pump rate (cubic feet/min)"]
            ##create a new well
            temp = Well(e, n, p, perm, pr, ym, ws, os, thick, prop, pump, name, RF, ap, FVF, oil, water)
            ##append the new well to the list
            wells.append(temp)

    createWells()

# %% [markdown]
# # <span style="color:blue">This is a generalized function that facilitates easy graphing of any 2 variables</span>

# %%
bottom = cm.get_cmap('Oranges', 128)
newcolors = np.vstack((bottom(np.linspace(0, 1, 128))))[32:127]
newcmp = ListedColormap(newcolors, name='DarkerOrange')

def makeGraph(xProp, xIsMethod, yProp, yIsMethod, xLabel, yLabel, zProp=-1, zIsMethod=-1, zRepeat=1, zLabel=""):
    #Graph anything
    xCoords = []
    yCoords = []
    zCoords = []
    for well in wells:
        xAttr = getattr(well, xProp)
        yAttr = getattr(well, yProp)
        zAttr = getattr(well, zProp) if zProp is not -1 else -1
        xCoords.append(xAttr() if xIsMethod else xAttr)
        yCoords.append(yAttr() if yIsMethod else yAttr)
        zCoords.append(zAttr() if zIsMethod else zAttr) if zAttr is not -1 else -1
    xCoords = np.array(xCoords).reshape(-1)
    yCoords = np.array(yCoords).reshape(-1)
    zCoords = np.array(zCoords).repeat(zRepeat).reshape(-1)
    plt.figure(dpi=100)
    if zAttr is -1:
        plt.scatter(xCoords, yCoords, s = 4)
    else:
        plt.scatter(xCoords, yCoords, s = 4, c=zCoords, cmap=newcmp)
        plt.colorbar().set_label(zLabel)
    plt.xlabel(xLabel)
    plt.ylabel(yLabel)

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Easting (ft)</span>

# %%
makeGraph("eastingAvg", True, "getTotalProduction", True, "Easting", "Total Production")

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Northing (ft)</span>

# %%
makeGraph("northingAvg", True, "getTotalProduction", True, "Northing", "Total Production")

# %% [markdown]
# # <span style="color:blue">Location of wells colored by Permeability

# %%
makeGraph("easting", False, "northing", False, "Easting", "Northing", zProp="permeabilityAvg", zIsMethod=True, zRepeat=100, zLabel="Permeability Avg")

# %% [markdown]
# # <span style="color:blue">Location of wells colored by Total Production (bbl)</span>

# %%
makeGraph("easting", False, "northing", False, "Easting", "Northing", zProp="getTotalProduction", zIsMethod=True, zRepeat=100, zLabel="Total Oil Production")

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Well Length (ft)</span>

# %%
makeGraph("getWellLength", True, "getTotalProduction", True, "Well Length", "Total Production")

# %% [markdown]
# # <span style="color:blue">Frequency Plot of Well Lengths (ft)</span>

# %%
lengths = []
for well in wells:
    lengths.append(well.getWellLength())
plt.hist(lengths);
plt.xlabel("Well Length")
plt.ylabel("# of Occurrences");

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Mean Pump Rate (ft<sup>3</sup>/min)</span>

# %%
makeGraph("getAvgPumpRate", True, "getTotalProduction", True, "Average Pump Rate", "Total Production")

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Mean Proppant (lbs)</span>

# %%
makeGraph("getAvgProppant", True, "getTotalProduction", True, "Average Proppant", "Total Production")

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Number of Frac Stages</span>

# %%
makeGraph("getFracStages", True, "getTotalProduction", True, "# Frac Stages", "Total Production")

# %% [markdown]
# # <span style="color:blue">Location of wells colored by Pump Rate (ft<sup>3</sup>/min)</span>

# %%
makeGraph("easting", False, "northing", False, "Easting", "Northing", zProp="pumpRate", zIsMethod=False, zLabel="Pump Rate")

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Mean Porosity</span>

# %%
makeGraph("porosityAvg", True, "getTotalProduction", True, "Porosity Avg", "Total Production", zProp="permeabilityAvg", zIsMethod=True, zLabel="Permeability Avg")

# %% [markdown]
# # <span style="color:blue">Location of wells colored by Porosity</span>

# %%
makeGraph("easting", False, "northing", False, "Easting", "Northing", zProp="porosity", zIsMethod=False, zLabel="Porosity")

# %% [markdown]
# # should we add a permeability location plot?

# %% [markdown]
# # <span style="color:blue">Making the 10 optimal wells</span>

# %%
addedWells = [
    np.linspace([86430, 5000], [95430, 5000], 100),
    np.linspace([66000, 2000], [76000, 2000], 100),
    np.linspace([85500, 19500], [90500, 19500], 100),
    np.linspace([71500, 20275], [76000, 20275], 100),
    np.linspace([59750, 20750], [64250, 20750], 100),
    np.linspace([64000, 22500], [70500, 22500], 100),
    np.linspace([63000, 33500], [69000, 33500], 100),
    np.linspace([4125, 26000], [11875, 26000], 100),
    np.linspace([53000, 59250], [64750, 59250], 100),
    np.linspace([63750, 64750], [74250, 64750], 100)
]
addedWellClasses = [Well(adde[:,0], adde[:,1], None, None, None, None, None, None, None, None,
                 None, None, None, None, 1.6, None, None) for adde in addedWells]

# %% [markdown]
# # <span style="color:blue">Making the Neural Network</span>

# %%
class NNetwork:
    def parseData(self, targetProperty, isTargetMethod, yLabel, yRepeat=1):
        self.yLabel = yLabel
        self.X = np.array([np.array([well.easting, well.northing]).transpose() for well in wells]).reshape(-1,2)
        self.y = np.array([np.array(getattr(well, targetProperty)).repeat(yRepeat) for well in wells]).reshape(-1)
        
        self.X = self.X[::25]
        self.y = self.y[::25]

        if isTargetMethod:
            self.y = np.array([a() for a in self.y])

        self.scalarX = MinMaxScaler()
        self.scalarX.fit(self.X)
        self.Xfit = self.scalarX.transform(self.X)
        self.scalarY = MinMaxScaler()
        self.scalarY.fit(self.y.reshape(-1,1))
        self.yfit = self.scalarY.transform(self.y.reshape(-1,1)).reshape(-1)

    def train(self):
        # Definition of our model
        self.model = keras.Sequential() # as first layer in a sequential model:
        # let's define our model:
        self.model.add( keras.layers.Dense( units=30, input_shape=(2,), activation="relu" ) )
        self.model.add( keras.layers.Dense( units=15, input_shape=(30,), activation="relu" ) )
        self.model.add( keras.layers.Dense( units=15, input_shape=(15,), activation="relu" ) )
        self.model.add( keras.layers.Dense( units=1, input_shape=(15,), activation="linear" ) )
        optimizer = keras.optimizers.Adam()
        self.model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_squared_error'])
        self.model.fit(self.Xfit, self.yfit, epochs=3000, verbose=1, batch_size=200, validation_split = 0.1)

        
    def plotSimple(self):
        testX0 = np.linspace(min(self.Xfit[:,0]), max(self.Xfit[:,0]), 50)
        testX1 = np.linspace(min(self.Xfit[:,1]), max(self.Xfit[:,1]), 50)
        grid0, grid1 = np.meshgrid(testX0, testX1)
        cost = np.array([self.model.predict(np.array([grid0[i], grid1[i]]).transpose()).reshape(-1) for i in range(len(grid0))])
        plt.pcolormesh(grid0,grid1,cost, norm=colors.SymLogNorm(linthresh=10, linscale=1,
                                                  vmin=cost.min(), vmax=cost.max()))
        plt.scatter(self.Xfit[:,0], self.Xfit[:,1], c = self.yfit)
        plt.scatter(np.array([self.scalarX.transform(addedWell)[:,0] for addedWell in addedWells]).reshape(-1), np.array([self.scalarX.transform(addedWell)[:,1] for addedWell in addedWells]).reshape(-1), c="#A00000")
        plt.colorbar().set_label(self.yLabel)
        plt.xlabel("Easting")
        plt.ylabel("Northing")
        plt.show()
        
    # Doesn't work properly yet - don't use ATM
    def plotAdvanced(self):
        testX0 = np.linspace(min(self.Xfit[:,0]), max(self.Xfit[:,0]), 50)
        testX1 = np.linspace(min(self.Xfit[:,1]), max(self.Xfit[:,1]), 50)
        grid0, grid1 = np.meshgrid(testX0, testX1)
        cost = np.array([self.model.predict(np.array([grid0[i], grid1[i]]).transpose()).reshape(-1) for i in range(len(grid0))])
        
        cost = self.scalarY.inverse_transform(cost)
        
        reset = self.scalarX.inverse_transform(np.array([testX0, testX1]).transpose())
        testX00 = reset[:,0]
        testX01 = reset[:,1]
        grid0, grid1 = np.meshgrid(testX00, testX01)
        
        plt.pcolormesh(grid0,grid1,cost, norm=colors.SymLogNorm(linthresh=10, linscale=1,
                                                  vmin=cost.min(), vmax=cost.max()))
        plt.scatter(self.X[:,0], self.X[:,1], c = self.y)
        plt.colorbar().set_label(self.yLabel)
        plt.xlabel("Easting")
        plt.ylabel("Northing")
        plt.show()
        
    def getNetwork(self):
        return (self.model, self.scalarX, self.scalarY)

# %%
porosityNet = NNetwork()
thicknessNet = NNetwork()
wSaturationNet = NNetwork()
RFNet = NNetwork()
totalOilNet = NNetwork()

porosityNet.parseData("porosity", False, "Porosity")
thicknessNet.parseData("thickness", False, "Thickness")
wSaturationNet.parseData("wSaturation", False, "Water Saturation")
RFNet.parseData("RF", False, "Recovery Factor", yRepeat=100)
totalOilNet.parseData("getTotalProduction", True, "Total Oil Production", yRepeat=100)

# %% [markdown]
# # <span style="color:blue">Training the Neural Network</span>

# %%
porosityNet.train()
thicknessNet.train()
wSaturationNet.train()
RFNet.train()
totalOilNet.train()
# Out:
# Train on 360 samples, validate on 40 samples
# Epoch 1/3000
# 360/360 [==============================] - 0s 962us/step - loss: 0.3530 - mean_squared_error: 0.3530 - val_loss: 0.4505 - val_mean_squared_error: 0.4505
# Epoch 2/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.3271 - mean_squared_error: 0.3271 - val_loss: 0.4257 - val_mean_squared_error: 0.4257
# Epoch 3/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.3030 - mean_squared_error: 0.3030 - val_loss: 0.4026 - val_mean_squared_error: 0.4026
# Epoch 4/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.2804 - mean_squared_error: 0.2804 - val_loss: 0.3796 - val_mean_squared_error: 0.3796
# Epoch 5/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.2594 - mean_squared_error: 0.2594 - val_loss: 0.3585 - val_mean_squared_error: 0.3585
# Epoch 6/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.2393 - mean_squared_error: 0.2393 - val_loss: 0.3388 - val_mean_squared_error: 0.3388
# Epoch 7/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.2208 - mean_squared_error: 0.2208 - val_loss: 0.3196 - val_mean_squared_error: 0.3196
# Epoch 8/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.2040 - mean_squared_error: 0.2040 - val_loss: 0.3010 - val_mean_squared_error: 0.3010
# Epoch 9/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.1879 - mean_squared_error: 0.1879 - val_loss: 0.2827 - val_mean_squared_error: 0.2827
# Epoch 10/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.1725 - mean_squared_error: 0.1725 - val_loss: 0.2650 - val_mean_squared_error: 0.2650
# Epoch 11/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.1579 - mean_squared_error: 0.1579 - val_loss: 0.2480 - val_mean_squared_error: 0.2480
# Epoch 12/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.1439 - mean_squared_error: 0.1439 - val_loss: 0.2317 - val_mean_squared_error: 0.2317
# Epoch 13/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.1310 - mean_squared_error: 0.1310 - val_loss: 0.2161 - val_mean_squared_error: 0.2161
# Epoch 14/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.1196 - mean_squared_error: 0.1196 - val_loss: 0.2014 - val_mean_squared_error: 0.2014
# Epoch 15/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.1091 - mean_squared_error: 0.1091 - val_loss: 0.1876 - val_mean_squared_error: 0.1876
# Epoch 16/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.1005 - mean_squared_error: 0.1005 - val_loss: 0.1748 - val_mean_squared_error: 0.1748
# Epoch 17/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0925 - mean_squared_error: 0.0925 - val_loss: 0.1632 - val_mean_squared_error: 0.1632
# Epoch 18/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0864 - mean_squared_error: 0.0864 - val_loss: 0.1523 - val_mean_squared_error: 0.1523
# Epoch 19/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0806 - mean_squared_error: 0.0806 - val_loss: 0.1423 - val_mean_squared_error: 0.1423
# Epoch 20/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0761 - mean_squared_error: 0.0761 - val_loss: 0.1331 - val_mean_squared_error: 0.1331
# Epoch 21/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0726 - mean_squared_error: 0.0726 - val_loss: 0.1248 - val_mean_squared_error: 0.1248
# Epoch 22/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0696 - mean_squared_error: 0.0696 - val_loss: 0.1172 - val_mean_squared_error: 0.1172
# Epoch 23/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0666 - mean_squared_error: 0.0666 - val_loss: 0.1101 - val_mean_squared_error: 0.1101
# Epoch 24/3000
# 360/360 [==============================] - 0s 30us/step - loss: 0.0639 - mean_squared_error: 0.0639 - val_loss: 0.1035 - val_mean_squared_error: 0.1035
# Epoch 25/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0613 - mean_squared_error: 0.0613 - val_loss: 0.0973 - val_mean_squared_error: 0.0973
# Epoch 26/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0585 - mean_squared_error: 0.0585 - val_loss: 0.0916 - val_mean_squared_error: 0.0916
# Epoch 27/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0558 - mean_squared_error: 0.0558 - val_loss: 0.0861 - val_mean_squared_error: 0.0861
# Epoch 28/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0531 - mean_squared_error: 0.0531 - val_loss: 0.0809 - val_mean_squared_error: 0.0809
# Epoch 29/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0504 - mean_squared_error: 0.0504 - val_loss: 0.0761 - val_mean_squared_error: 0.0761
# Epoch 30/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0478 - mean_squared_error: 0.0478 - val_loss: 0.0716 - val_mean_squared_error: 0.0716
# Epoch 31/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0453 - mean_squared_error: 0.0453 - val_loss: 0.0675 - val_mean_squared_error: 0.0675
# Epoch 32/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0429 - mean_squared_error: 0.0429 - val_loss: 0.0639 - val_mean_squared_error: 0.0639
# Epoch 33/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0408 - mean_squared_error: 0.0408 - val_loss: 0.0605 - val_mean_squared_error: 0.0605
# Epoch 34/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0573 - val_mean_squared_error: 0.0573
# Epoch 35/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.
3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 75/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 76/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 77/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 78/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 79/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 80/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 81/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 82/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 83/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 84/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 85/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 86/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 87/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 88/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 89/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 90/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Epoch 91/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 92/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 93/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 94/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 95/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Epoch 96/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 97/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 98/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0222 - val_mean_squared_error: 0.0222
# Epoch 99/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 100/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 101/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0226 - val_mean_squared_error: 0.0226
# Epoch 102/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0226 - val_mean_squared_error: 0.0226
# Epoch 103/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 104/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 105/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 106/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 107/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 108/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 109/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 110/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 111/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 112/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 113/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 114/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 115/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0216 - val_mean_squared_error: 0.0216
# Epoch 116/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 117/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# Epoch 118/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 119/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0212 - val_mean_squared_error: 0.0212
# Epoch 120/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0212 - val_mean_squared_error: 0.0212
# Epoch 121/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0212 - val_mean_squared_error: 0.0212
# Epoch 122/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 123/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0210 - val_mean_squared_error: 0.0210
# Epoch 124/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0210 - val_mean_squared_error: 0.0210
# Epoch 125/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# Epoch 126/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0210 - val_mean_squared_error: 0.0210
# Epoch 127/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# Epoch 128/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# Epoch 129/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 130/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 131/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 132/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 133/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 134/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 135/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 136/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 137/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 138/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 139/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 140/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 141/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 142/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 143/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 144/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 145/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 146/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 147/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 148/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 149/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 150/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 151/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 152/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 153/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0195 - val_mean_squared_error: 0.0195
# Epoch 154/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0193 - val_mean_squared_error: 0.0193
# Epoch 155/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 156/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
# Epoch 157/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 158/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0192 - val_mean_squared_error: 0.0192
# Epoch 159/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0194 - val_mean_squared_error: 0.0194
# Epoch 160/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 161/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 162/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 163/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 164/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 165/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 166/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 167/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 168/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 169/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 170/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 171/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.
-04 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 2981/3000
# 360/360 [==============================] - 0s 14us/step - loss: 1.0507e-04 - mean_squared_error: 1.0507e-04 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 2982/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.0542e-04 - mean_squared_error: 1.0542e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 2983/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.1056e-04 - mean_squared_error: 1.1056e-04 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 2984/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.0735e-04 - mean_squared_error: 1.0735e-04 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 2985/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.0332e-04 - mean_squared_error: 1.0332e-04 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 2986/3000
# 360/360 [==============================] - 0s 8us/step - loss: 1.0941e-04 - mean_squared_error: 1.0941e-04 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 2987/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.0331e-04 - mean_squared_error: 1.0331e-04 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 2988/3000
# 360/360 [==============================] - 0s 14us/step - loss: 1.0676e-04 - mean_squared_error: 1.0676e-04 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 2989/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.0456e-04 - mean_squared_error: 1.0456e-04 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 2990/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.0657e-04 - mean_squared_error: 1.0657e-04 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 2991/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.1191e-04 - mean_squared_error: 1.1191e-04 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 2992/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.0766e-04 - mean_squared_error: 1.0766e-04 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 2993/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.0864e-04 - mean_squared_error: 1.0864e-04 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 2994/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.0823e-04 - mean_squared_error: 1.0823e-04 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 2995/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.1910e-04 - mean_squared_error: 1.1910e-04 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 2996/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.3228e-04 - mean_squared_error: 1.3228e-04 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 2997/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.1132e-04 - mean_squared_error: 1.1132e-04 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 2998/3000
# 360/360 [==============================] - 0s 14us/step - loss: 1.1684e-04 - mean_squared_error: 1.1684e-04 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 2999/3000
# 360/360 [==============================] - 0s 14us/step - loss: 1.2145e-04 - mean_squared_error: 1.2145e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 3000/3000
# 360/360 [==============================] - 0s 11us/step - loss: 1.1704e-04 - mean_squared_error: 1.1704e-04 - val_loss: 0.0026 - val_mean_squared_error: 0.0026

# %%
# for use in powerpoint
porosityNet.plotSimple()
thicknessNet.plotSimple()
wSaturationNet.plotSimple()
RFNet.plotSimple()
totalOilNet.plotSimple()

# %%
# use the neural networks to populate well classes for the wells we create
for addedWellClass in addedWellClasses:
    addedWellClass.thickness = thicknessNet.scalarY.inverse_transform(thicknessNet.model.predict(thicknessNet.scalarX.transform(np.array([addedWellClass.easting, addedWellClass.northing]).transpose()))).reshape(-1)
    addedWellClass.porosity = porosityNet.scalarY.inverse_transform(porosityNet.model.predict(porosityNet.scalarX.transform(np.array([addedWellClass.easting, addedWellClass.northing]).transpose()))).reshape(-1)
    addedWellClass.wSaturation = wSaturationNet.scalarY.inverse_transform(wSaturationNet.model.predict(wSaturationNet.scalarX.transform(np.array([addedWellClass.easting, addedWellClass.northing]).transpose()))).reshape(-1)
    addedWellClass.RF = RFNet.scalarY.inverse_transform(RFNet.model.predict(RFNet.scalarX.transform(np.array([addedWellClass.easting, addedWellClass.northing]).transpose()))).reshape(-1).mean()
    totalOil = totalOilNet.scalarY.inverse_transform(totalOilNet.model.predict(totalOilNet.scalarX.transform(np.array([addedWellClass.easting, addedWellClass.northing]).transpose()))).reshape(-1).mean()
    addedWellClass.oilByMonth = np.array(totalOil/12).repeat(12)

# %%
#OOIP
np.array([addedWellClass.getOilInPlace() for addedWellClass in addedWellClasses]).sum()

# %%
#RR
np.array([addedWellClass.getRecoverableReserves() for addedWellClass in addedWellClasses]).sum()

# %%
#EUR
np.array([addedWellClass.getTotalProduction() for addedWellClass in addedWellClasses]).sum()
