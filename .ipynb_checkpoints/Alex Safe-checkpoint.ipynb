# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
import keras
from keras.layers import Dense
import matplotlib.colors as colors
wells = []
##global scope variable for the path to where all the well data is stored
_PATH = "Data/"
# Out:
# Using TensorFlow backend.
# C:\Users\alex2\Anaconda3\envs\energyanalytics\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\alex2\Anaconda3\envs\energyanalytics\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\alex2\Anaconda3\envs\energyanalytics\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\alex2\Anaconda3\envs\energyanalytics\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\alex2\Anaconda3\envs\energyanalytics\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\alex2\Anaconda3\envs\energyanalytics\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # <span style="color:blue">This is a well class that will hold all the properties of a well and also will be able to perform relevant calculations for a given well</span>

# %%
class Well:
    ##This is a well class that will hold all the properties of a well
    ##and also will be able to do relevant calculations for a given well
    
    ##Once the data is set in the constructor, please do not change the values when they are accessed.
    ##Apparently I can't prevent this in Python, but I can at least advise against it.
    
    def __init__(self, easting, northing, porosity, permeability, PR, YM, wSaturation, oSaturation, thickness, proppant,
                 pumpRate, name, RF, Pa, FVF, oilByMonth, waterByMonth):
        self.easting = easting ##easting, areas with higher
        self.northing = northing ##northing, areas with higher
        self.porosity = porosity ##porosity, definitely something there
        self.permeability = permeability ##permeability,definitely something there
        self.PR = PR ##poissons's ratio, might be something. couple of outliers but general convergence
        self.YM = YM ##young's modulus, pyramid shape, probably something
        self.wSaturation = wSaturation ##water saturation, no correlation to production
        self.oSaturation = oSaturation ##oil saturation, no correlation to production
        self.thickness = thickness ##thickness, no correlation to production
        self.proppant = proppant ##proppant weight, maybe a correlation
        self.pumpRate = pumpRate ##pumpRate, probably a correlation
        self.name = name ##name
        self.RF = RF ##recovery factor, maybe something
        self.Pa = Pa ##average pressure, probably something
        self.FVF = FVF ##formation volume factor
        self.oilByMonth = oilByMonth ##oil produced in each month
        self.waterByMonth = waterByMonth ##water produced in each month
    
    ##returns the length of the well
    def getWellLength(self):
        return self.easting.max()-self.easting.min()
    
    #returns the total oil produced by the well
    def getTotalProduction(self):
        return self.oilByMonth.sum()
    
    ##returns the oil in place for this given well
    def getOilInPlace(self):
        return ((7758 * 360 * self.thickness.mean() * self.porosity.mean() * (1 - self.wSaturation.mean())) / self.FVF)
    
    ##returns the recoverable reserves of this well
    def getRecoverableReserves(self):
        return (self.getOilInPlace() * self.RF)
    
    ##Returns the production rate
    def InitialProduction(self):
        return (self.oilByMonth[0] * (math.exp((-1 * ((self.oilByMonth[11] - self.oilByMonth[0]) / 12) * time))))
        ##need to figure out how to plug in time (otherwise it will always equal first month production). also could be used
        ##to find the decline over time (where time is difference in production)
    
    ##Returns the economic limit of production
    def economicLimitROP(self):
        sumOilProduction = 0 
        for i in range(12):
            oil = getOilAtMonth(self, i)
            water = getWaterAtMonth(self, i)
            sumOilProduction += oil
            if(oil < water):
                return sumOilProduction
    
    ##Returns time in years
    def LifeOfReservoir(self):
        return ((1 / ((self.oilByMonth[11] - self.oilByMonth[0]) / 12)) * math.log((self.oilbyMonth[0]) / economicLimitROP(self)))
    
    ##Returns cumulative production in bbl
    def CumulativeProduction(self):
        return ((self.oilbyMonth[0] / declineRate) * math.log(self.oilbyMonth[0] / self.oilbyMonth[11]))
    
    ##this is the kind of functioning as a toString right now, almost no reason for it
    def getName(self):
        return self.name
    
    ##method to return oil produced in a given month
    def getOilAtMonth(self, n):
        if n > 12 or n < 1:
            ##bad
            return -1
        else:
            return self.oilByMonth[n]
    
    ##method to return water produced in a given month
    def getOilAtMonth(self, n):
        if n > 12 or n < 1:
            ##bad
            return -1
        else:
            return self.waterByMonth[n]
    
    ##method to display data for this well
    ##depth will be for getiing data at a given depth in a well. Not sure if or when I should implement this
    def displayData(self, depth = 0):
        if depth == 0:
            data = pd.read_csv(_PATH + self.name + ".csv")
        else:
            data = pd.read_csv(_PATH + self.name + ".csv")
            
        print("Displaying data for: " + self.name)
        print(data)
    
    ##Returns the number of frac stages for a well
    def getFracStages(self):
        count = 0
        for rate in self.pumpRate:
            if (pd.notnull(rate)):
                count+=1
        return count
    
    ##Returns the mean pump rate of a well
    def getAvgPumpRate(self):
        return self.pumpRate.mean(skipna = True)
    
    ##Returns the mean amount of proppant used in a well
    def getAvgProppant(self):
        return self.proppant.mean(skipna = True)
    
    ##Returns the mean easting coordinate value of a well
    def eastingAvg(self):
        return np.array(self.easting).mean()
    
    ##Returns the mean northing coordinate value of a well
    def northingAvg(self):
        return np.array(self.northing).mean()
    
    ##Returns the mean porosity value of a well
    def porosityAvg(self):
        return np.array(self.porosity).mean()
    
    ##Returns the mean permeability value of a well
    def permeabilityAvg(self):
        return np.array(self.permeability).mean()

    ##method to take the data given, create a well object and store it in wells
    def createWells():
        wellProduction = pd.read_csv(_PATH + "well production.csv")
        for i in range(100):
        ##for every well
            ##get all the data from the well production csv
            name = wellProduction.at[i, "well name"]
            ap = wellProduction.at[i, "average pressure (Pa)"]
            RF = wellProduction.at[i, "recovery factor"]
            FVF = wellProduction.at[i, "formation volume factor"]
            oil = wellProduction.iloc[i, 4:16] ##oil per month
            water = wellProduction.iloc[i, 16:28] ##water per month
            ##now that we have the name of the well, we can use that to access its
            ##own csv file and get that data
            wellDF = pd.read_csv(_PATH + name + ".csv")
            e = wellDF["easting"]
            n = wellDF["northing"]
            p = wellDF["porosity"]
            perm = wellDF["permeability"]
            pr = wellDF["Poisson's ratio"]
            ym = wellDF["Young's Modulus"]
            ws = wellDF["water saturation"]
            os = wellDF["oil saturation"]
            thick = wellDF["thickness (ft)"]
            prop = wellDF["proppant weight (lbs)"]
            pump = wellDF["pump rate (cubic feet/min)"]
            ##create a new well
            temp = Well(e, n, p, perm, pr, ym, ws, os, thick, prop, pump, name, RF, ap, FVF, oil, water)
            ##append the new well to the list
            wells.append(temp)

    createWells()

# %% [markdown]
# # <span style="color:blue">This is a generalized function that facilitates easy graphing of any 2 variables</span>

# %%
bottom = cm.get_cmap('Oranges', 128)
newcolors = np.vstack((bottom(np.linspace(0, 1, 128))))[32:127]
newcmp = ListedColormap(newcolors, name='DarkerOrange')

def makeGraph(xProp, xIsMethod, yProp, yIsMethod, xLabel, yLabel, zProp=-1, zIsMethod=-1, zRepeat=1, zLabel=""):
    #Graph anything
    xCoords = []
    yCoords = []
    zCoords = []
    for well in wells:
        xAttr = getattr(well, xProp)
        yAttr = getattr(well, yProp)
        zAttr = getattr(well, zProp) if zProp is not -1 else -1
        xCoords.append(xAttr() if xIsMethod else xAttr)
        yCoords.append(yAttr() if yIsMethod else yAttr)
        zCoords.append(zAttr() if zIsMethod else zAttr) if zAttr is not -1 else -1
    xCoords = np.array(xCoords).reshape(-1)
    yCoords = np.array(yCoords).reshape(-1)
    zCoords = np.array(zCoords).repeat(zRepeat).reshape(-1)
    plt.figure(dpi=100)
    if zAttr is -1:
        plt.scatter(xCoords, yCoords, s = 4)
    else:
        plt.scatter(xCoords, yCoords, s = 4, c=zCoords, cmap=newcmp)
        plt.colorbar().set_label(zLabel)
    plt.xlabel(xLabel)
    plt.ylabel(yLabel)

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Easting (ft)</span>

# %%
makeGraph("eastingAvg", True, "getTotalProduction", True, "Easting", "Total Production")

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Northing (ft)</span>

# %%
makeGraph("northingAvg", True, "getTotalProduction", True, "Northing", "Total Production")

# %% [markdown]
# # <span style="color:blue">Location of wells colored by Permeability

# %%
makeGraph("easting", False, "northing", False, "Easting", "Northing", zProp="permeabilityAvg", zIsMethod=True, zRepeat=100, zLabel="Permeability Avg")

# %% [markdown]
# # <span style="color:blue">Location of wells colored by Total Production (bbl)</span>

# %%
makeGraph("easting", False, "northing", False, "Easting", "Northing", zProp="getTotalProduction", zIsMethod=True, zRepeat=100, zLabel="Total Oil Production")

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Well Length (ft)</span>

# %%
makeGraph("getWellLength", True, "getTotalProduction", True, "Well Length", "Total Production")

# %% [markdown]
# # <span style="color:blue">Frequency Plot of Well Lengths (ft)</span>

# %%
lengths = []
for well in wells:
    lengths.append(well.getWellLength())
plt.hist(lengths);
plt.xlabel("Well Length")
plt.ylabel("# of Occurrences");

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Mean Pump Rate (ft<sup>3</sup>/min)</span>

# %%
makeGraph("getAvgPumpRate", True, "getTotalProduction", True, "Average Pump Rate", "Total Production")

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Mean Proppant (lbs)</span>

# %%
makeGraph("getAvgProppant", True, "getTotalProduction", True, "Average Proppant", "Total Production")

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Number of Frac Stages</span>

# %%
makeGraph("getFracStages", True, "getTotalProduction", True, "# Frac Stages", "Total Production")

# %% [markdown]
# # <span style="color:blue">Location of wells colored by Pump Rate (ft<sup>3</sup>/min)</span>

# %%
makeGraph("easting", False, "northing", False, "Easting", "Northing", zProp="pumpRate", zIsMethod=False, zLabel="Pump Rate")

# %% [markdown]
# # <span style="color:blue">Total Production (bbl) vs Mean Porosity</span>

# %%
makeGraph("porosityAvg", True, "getTotalProduction", True, "Porosity Avg", "Total Production", zProp="permeabilityAvg", zIsMethod=True, zLabel="Permeability Avg")

# %% [markdown]
# # <span style="color:blue">Location of wells colored by Porosity</span>

# %%
makeGraph("easting", False, "northing", False, "Easting", "Northing", zProp="porosity", zIsMethod=False, zLabel="Porosity")

# %% [markdown]
# # should we add a permeability location plot?

# %% [markdown]
# # <span style="color:blue">Making the 10 optimal wells</span>

# %%
addedWells = [
    np.linspace([86430, 5000], [95430, 5000], 100),
    np.linspace([66000, 2000], [76000, 2000], 100),
    np.linspace([85500, 19500], [90500, 19500], 100),
    np.linspace([71500, 20275], [76000, 20275], 100),
    np.linspace([59750, 20750], [64250, 20750], 100),
    np.linspace([64000, 22500], [70500, 22500], 100),
    np.linspace([63000, 33500], [69000, 33500], 100),
    np.linspace([4125, 26000], [11875, 26000], 100),
    np.linspace([53000, 59250], [64750, 59250], 100),
    np.linspace([63750, 64750], [74250, 64750], 100)
]
addedWellClasses = [Well(adde[:,0], adde[:,1], None, None, None, None, None, None, None, None,
                 None, None, None, None, 1.6, None, None) for adde in addedWells]

# %% [markdown]
# # <span style="color:blue">Making the Neural Network</span>

# %%
class NNetwork:
    def parseData(self, targetProperty, isTargetMethod, yLabel, yRepeat=1):
        self.yLabel = yLabel
        self.X = np.array([np.array([well.easting, well.northing]).transpose() for well in wells]).reshape(-1,2)
        self.y = np.array([np.array(getattr(well, targetProperty)).repeat(yRepeat) for well in wells]).reshape(-1)
        
        self.X = self.X[::25]
        self.y = self.y[::25]

        if isTargetMethod:
            self.y = np.array([a() for a in self.y])

        self.scalarX = MinMaxScaler()
        self.scalarX.fit(self.X)
        self.Xfit = self.scalarX.transform(self.X)
        self.scalarY = MinMaxScaler()
        self.scalarY.fit(self.y.reshape(-1,1))
        self.yfit = self.scalarY.transform(self.y.reshape(-1,1)).reshape(-1)

    def train(self):
        # Definition of our model
        self.model = keras.Sequential() # as first layer in a sequential model:
        # let's define our model:
        self.model.add( keras.layers.Dense( units=30, input_shape=(2,), activation="relu" ) )
        self.model.add( keras.layers.Dense( units=15, input_shape=(30,), activation="relu" ) )
        self.model.add( keras.layers.Dense( units=15, input_shape=(15,), activation="relu" ) )
        self.model.add( keras.layers.Dense( units=1, input_shape=(15,), activation="linear" ) )
        optimizer = keras.optimizers.Adam()
        self.model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_squared_error'])
        self.model.fit(self.Xfit, self.yfit, epochs=3000, verbose=1, batch_size=200, validation_split = 0.1)

        
    def plotSimple(self):
        testX0 = np.linspace(min(self.Xfit[:,0]), max(self.Xfit[:,0]), 50)
        testX1 = np.linspace(min(self.Xfit[:,1]), max(self.Xfit[:,1]), 50)
        grid0, grid1 = np.meshgrid(testX0, testX1)
        cost = np.array([self.model.predict(np.array([grid0[i], grid1[i]]).transpose()).reshape(-1) for i in range(len(grid0))])
        plt.pcolormesh(grid0,grid1,cost, norm=colors.SymLogNorm(linthresh=10, linscale=1,
                                                  vmin=cost.min(), vmax=cost.max()))
        plt.scatter(self.Xfit[:,0], self.Xfit[:,1], c = self.yfit)
        plt.scatter(np.array([self.scalarX.transform(addedWell)[:,0] for addedWell in addedWells]).reshape(-1), np.array([self.scalarX.transform(addedWell)[:,1] for addedWell in addedWells]).reshape(-1), c="#A00000")
        plt.colorbar().set_label(self.yLabel)
        plt.xlabel("Easting")
        plt.ylabel("Northing")
        plt.show()
        
    # Doesn't work properly yet - don't use ATM
    def plotAdvanced(self):
        testX0 = np.linspace(min(self.Xfit[:,0]), max(self.Xfit[:,0]), 50)
        testX1 = np.linspace(min(self.Xfit[:,1]), max(self.Xfit[:,1]), 50)
        grid0, grid1 = np.meshgrid(testX0, testX1)
        cost = np.array([self.model.predict(np.array([grid0[i], grid1[i]]).transpose()).reshape(-1) for i in range(len(grid0))])
        
        cost = self.scalarY.inverse_transform(cost)
        
        reset = self.scalarX.inverse_transform(np.array([testX0, testX1]).transpose())
        testX00 = reset[:,0]
        testX01 = reset[:,1]
        grid0, grid1 = np.meshgrid(testX00, testX01)
        
        plt.pcolormesh(grid0,grid1,cost, norm=colors.SymLogNorm(linthresh=10, linscale=1,
                                                  vmin=cost.min(), vmax=cost.max()))
        plt.scatter(self.X[:,0], self.X[:,1], c = self.y)
        plt.colorbar().set_label(self.yLabel)
        plt.xlabel("Easting")
        plt.ylabel("Northing")
        plt.show()
        
    def getNetwork(self):
        return (self.model, self.scalarX, self.scalarY)

# %%
porosityNet = NNetwork()
thicknessNet = NNetwork()
wSaturationNet = NNetwork()
RFNet = NNetwork()
totalOilNet = NNetwork()

porosityNet.parseData("porosity", False, "Porosity")
thicknessNet.parseData("thickness", False, "Thickness")
wSaturationNet.parseData("wSaturation", False, "Water Saturation")
RFNet.parseData("RF", False, "Recovery Factor", yRepeat=100)
totalOilNet.parseData("getTotalProduction", True, "Total Oil Production", yRepeat=100)

# %% [markdown]
# # <span style="color:blue">Training the Neural Network</span>

# %%
porosityNet.train()
thicknessNet.train()
wSaturationNet.train()
RFNet.train()
totalOilNet.train()
# Out:
# WARNING:tensorflow:From C:\Users\alex2\Anaconda3\envs\energyanalytics\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\alex2\Anaconda3\envs\energyanalytics\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 360 samples, validate on 40 samples
# Epoch 1/3000
# 360/360 [==============================] - 0s 817us/step - loss: 0.3023 - mean_squared_error: 0.3023 - val_loss: 0.4148 - val_mean_squared_error: 0.4148
# Epoch 2/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.2810 - mean_squared_error: 0.2810 - val_loss: 0.3917 - val_mean_squared_error: 0.3917
# Epoch 3/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.2616 - mean_squared_error: 0.2616 - val_loss: 0.3686 - val_mean_squared_error: 0.3686
# Epoch 4/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.2423 - mean_squared_error: 0.2423 - val_loss: 0.3472 - val_mean_squared_error: 0.3472
# Epoch 5/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.2240 - mean_squared_error: 0.2240 - val_loss: 0.3251 - val_mean_squared_error: 0.3251
# Epoch 6/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.2061 - mean_squared_error: 0.2061 - val_loss: 0.3038 - val_mean_squared_error: 0.3038
# Epoch 7/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.1889 - mean_squared_error: 0.1889 - val_loss: 0.2838 - val_mean_squared_error: 0.2838
# Epoch 8/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.1735 - mean_squared_error: 0.1735 - val_loss: 0.2664 - val_mean_squared_error: 0.2664
# Epoch 9/3000
# 360/360 [==============================] - 0s 5us/step - loss: 0.1602 - mean_squared_error: 0.1602 - val_loss: 0.2509 - val_mean_squared_error: 0.2509
# Epoch 10/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.1482 - mean_squared_error: 0.1482 - val_loss: 0.2361 - val_mean_squared_error: 0.2361
# Epoch 11/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.1370 - mean_squared_error: 0.1370 - val_loss: 0.2215 - val_mean_squared_error: 0.2215
# Epoch 12/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0
- val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 121/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 122/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 123/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 124/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 125/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 126/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 127/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 128/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 129/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 130/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 131/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 132/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 133/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 134/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 135/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 136/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 137/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Epoch 138/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0226 - val_mean_squared_error: 0.0226
# Epoch 139/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 140/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 141/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 142/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 143/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0226 - val_mean_squared_error: 0.0226
# Epoch 144/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 145/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 146/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 147/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 148/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 149/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 150/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 151/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0222 - val_mean_squared_error: 0.0222
# Epoch 152/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 153/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 154/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 155/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 156/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 157/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 158/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 159/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 160/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 161/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0217 - val_mean_squared_error: 0.0217
# Epoch 162/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0217 - val_mean_squared_error: 0.0217
# Epoch 163/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0217 - val_mean_squared_error: 0.0217
# Epoch 164/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 165/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0217 - val_mean_squared_error: 0.0217
# Epoch 166/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0217 - val_mean_squared_error: 0.0217
# Epoch 167/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 168/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0217 - val_mean_squared_error: 0.0217
# Epoch 169/3000
# 360/360 [==============================] - ETA: 0s - loss: 0.0186 - mean_squared_error: 0.01 - 0s 11us/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 170/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# Epoch 171/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# Epoch 172/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 173/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0216 - val_mean_squared_error: 0.0216
# Epoch 174/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0216 - val_mean_squared_error: 0.0216
# Epoch 175/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0217 - val_mean_squared_error: 0.0217
# Epoch 176/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 177/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 178/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# Epoch 179/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0212 - val_mean_squared_error: 0.0212
# Epoch 180/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0212 - val_mean_squared_error: 0.0212
# Epoch 181/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 182/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 183/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 184/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0212 - val_mean_squared_error: 0.0212
# Epoch 185/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 186/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0212 - val_mean_squared_error: 0.0212
# Epoch 187/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# Epoch 188/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 189/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 190/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 191/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 192/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 193/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 194/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 195/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 196/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 197/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 198/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 199/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 200/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 201/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 202/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 203/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 204/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 205/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 206/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 207/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 208/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 209/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 210/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 211/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 212/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 213/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 214/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 215/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 216/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 217/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 218/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 219/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 220/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 221/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0192 - val_mean_squared_error: 0.0192
# Epoch 222/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 223/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 224/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 225/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0192 - val_mean_squared_error: 0.0192
# Epoch 226/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
# Epoch 227/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 228/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 229/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 230/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 231/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 232/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 233/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 234/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 235/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 236/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 237/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 238/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 239/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 240/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 241/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 242/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 243/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 244/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 245/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 246/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 247/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 248/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 249/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 250/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 251/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 252/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 253/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0163 - val_mean_squared_error: 0.0163
# Epoch 254/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0163 - val_mean_squared_error: 0.0163
# Epoch 255/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 256/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 257/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 258/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 259/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 260/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 261/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 262/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 263/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0154 - val_mean_squared_error: 0.0154
# Epoch 264/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 265/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 266/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0147 - val_mean_squared_error: 0.0147
# Epoch 267/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0144 - val_mean_squared_error: 0.0144
# Epoch 268/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 269/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 270/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 271/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# Epoch 272/3000
# 360/360 [==============================] - 0s 6us/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0143 - val_mean_squared_error: 0.0143
# Epoch 273/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 274/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0142 - val_mean_squared_error: 0.0142
# Epoch 275/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0143 - val_mean_squared_error: 0.0143
# Epoch 276/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0143 - val_mean_squared_error: 0.0143
# Epoch 277/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0145 - val_mean_squared_error: 0.0145
# Epoch 278/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0142 - val_mean_squared_error: 0.0142
# Epoch 279/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 280/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 281/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 282/3000
# 360/360 [==============================] - ETA: 0s - loss: 0.0136 - mean_squared_error: 0.01 - 0s 8us/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
# Epoch 283/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0144 - val_mean_squared_error: 0.0144
# Epoch 284/3000
# 360/360 [==============================] - 0s 8us/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 285/3000
# ...
# Epoch 2907/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 2908/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# Epoch 2909/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Epoch 2910/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 2911/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 2912/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0238 - val_mean_squared_error: 0.0238
# Epoch 2913/3000
# 360/360 [==============================] - ETA: 0s - loss: 0.0056 - mean_squared_error: 0.00 - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 2914/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 2915/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Epoch 2916/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
# Epoch 2917/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 2918/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 2919/3000
# 360/360 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.00 - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Epoch 2920/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0245 - val_mean_squared_error: 0.0245
# Epoch 2921/3000
# 360/360 [==============================] - ETA: 0s - loss: 0.0050 - mean_squared_error: 0.00 - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 2922/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 2923/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# Epoch 2924/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0216 - val_mean_squared_error: 0.0216
# Epoch 2925/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# Epoch 2926/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 2927/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0238 - val_mean_squared_error: 0.0238
# Epoch 2928/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 2929/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 2930/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 2931/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 2932/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 2933/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0226 - val_mean_squared_error: 0.0226
# Epoch 2934/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 2935/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 2936/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 2937/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# Epoch 2938/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0226 - val_mean_squared_error: 0.0226
# Epoch 2939/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 2940/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 2941/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 2942/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0248 - val_mean_squared_error: 0.0248
# Epoch 2943/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 2944/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 2945/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 2946/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 2947/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
# Epoch 2948/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 2949/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0254 - val_mean_squared_error: 0.0254
# Epoch 2950/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 2951/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 2952/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 2953/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 2954/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Epoch 2955/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0245 - val_mean_squared_error: 0.0245
# Epoch 2956/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 2957/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Epoch 2958/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# Epoch 2959/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 2960/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 2961/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 2962/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0238 - val_mean_squared_error: 0.0238
# Epoch 2963/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# Epoch 2964/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 2965/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 2966/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 2967/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 2968/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 2969/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 2970/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 2971/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 2972/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 2973/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 2974/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 2975/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 2976/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 2977/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
# Epoch 2978/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 2979/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# Epoch 2980/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Epoch 2981/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0222 - val_mean_squared_error: 0.0222
# Epoch 2982/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 2983/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 2984/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 2985/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 2986/3000
# 360/360 [==============================] - 0s 11us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 2987/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# Epoch 2988/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 2989/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 2990/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 2991/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 2992/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 2993/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# Epoch 2994/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 2995/3000
# 360/360 [==============================] - 0s 17us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 2996/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 2997/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 2998/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0247 - val_mean_squared_error: 0.0247
# Epoch 2999/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 3000/3000
# 360/360 [==============================] - 0s 14us/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0242 - val_mean_squared_error: 0.0242

# %%
# for use in powerpoint
porosityNet.plotSimple()
thicknessNet.plotSimple()
wSaturationNet.plotSimple()
RFNet.plotSimple()
totalOilNet.plotSimple()

# %%
# use the neural networks to populate well classes for the wells we create
for addedWellClass in addedWellClasses:
    addedWellClass.thickness = thicknessNet.scalarY.inverse_transform(thicknessNet.model.predict(thicknessNet.scalarX.transform(np.array([addedWellClass.easting, addedWellClass.northing]).transpose()))).reshape(-1)
    addedWellClass.porosity = porosityNet.scalarY.inverse_transform(porosityNet.model.predict(porosityNet.scalarX.transform(np.array([addedWellClass.easting, addedWellClass.northing]).transpose()))).reshape(-1)
    addedWellClass.wSaturation = wSaturationNet.scalarY.inverse_transform(wSaturationNet.model.predict(wSaturationNet.scalarX.transform(np.array([addedWellClass.easting, addedWellClass.northing]).transpose()))).reshape(-1)
    addedWellClass.RF = RFNet.scalarY.inverse_transform(RFNet.model.predict(RFNet.scalarX.transform(np.array([addedWellClass.easting, addedWellClass.northing]).transpose()))).reshape(-1).mean()
    totalOil = totalOilNet.scalarY.inverse_transform(totalOilNet.model.predict(totalOilNet.scalarX.transform(np.array([addedWellClass.easting, addedWellClass.northing]).transpose()))).reshape(-1).mean()
    addedWellClass.oilByMonth = np.array(totalOil/12).repeat(12)

# %%
#OOIP
np.array([addedWellClass.getOilInPlace() for addedWellClass in addedWellClasses]).sum()
# Out:
# 68300698.59325887

# %%
#RR
np.array([addedWellClass.getRecoverableReserves() for addedWellClass in addedWellClasses]).sum()
# Out:
# 6676856.319697338

# %%
#EUR
np.array([addedWellClass.getTotalProduction() for addedWellClass in addedWellClasses]).sum()
# Out:
# 34642.370361328125
